# %%
# DATA ANALYSIS WITH PYTHON

### INTRODUCTION

The dataset we will use for this analysis is gotten from FestMan. It's an hotel booking dataset. 
The purpose  of this project is to do some data anlysis with real life data using python. 

Here are the dataset columns.

1	Booking ID	= Unique Booking ID

2	Date of Booking	= Date of the Booking

3	Year	= Year of the Booking

4	Time	= Time of the Booking

5	Customer ID	= Unique ID of the booking customer

6	Gender	= Gender of the customer

7	Age	= Age of the customer

8	Origin Country	= Country of the customer

9	State	= State of the customer

10	Location	= City of the customer

11	Destination Country	= Destination country where the customer trip

12	Destination City	= Destination city where the customer trip

13	No. Of People	= Number of people going on the trip

14	Check-in date	= Check-in date for trip

15	No. Of Days	= Number of days of visit

16	Check-Out Date	= Check-out date of trip

17	Rooms	= Number of room booked

18	Hotel Name	= Hotel name where the booking is made

19	Hotel Rating	= The hotel rating

20	Payment Mode	= Mode of payment

21	Bank Name	= Payee Bank name

22	No. Of Days	= Number of days of visit

23	Rooms	= Number of room booked

24	Booking Price[SGD]	= Total Booking Charges

25	Discount	= Discount %

26	GST	= Goods and Service Tax %

27	Profit Margin	= Profit Margin %




As a data analyst, our analysis is used to answerd questions that help make informed decisions. 
we will answer the following question through our exploratory analysis:

1 Which is the most preferred hotel?

2 Which country are most visitors from?

3 What is the percentage of booking for each year?

4 Which is the bisiest month?

5 What is the most used payment mode?

6 What are the factors to concentrate on to increase revenue?

# %% [markdown]
# ### DATA PREPARATION

# %%
#importing necessary packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
#import data and copy data

original = r"C:\Users\Daisy\Desktop\Hostel Booking Challenge_FestMan.xlsx"
hotel = pd.read_excel(original)
hotel.head()
# Out:
#   Booking ID Date of Booking  Year      Time Customer ID  Gender  Age  \
# 0  DDMY00001      2010-01-01  2010  10:49:40     MY00001    Male   42
# 1  DDID00002      2010-01-01  2010  09:19:47     ID00001  Female   44
# 2  DDSG00003      2010-01-01  2010  11:52:56     SG00001  Female   31
# 3  DDSG00004      2010-01-01  2010  13:44:40     SG00002    Male   28
# 4  DDKH00005      2010-01-01  2010  05:38:26     KH00001    Male   44
#
#   Origin Country       State         Location  ...         Hotel Name  \
# 0       Malaysia       Johor  Iskandar Puteri  ...       Hotel Triton
# 1      Indonesia       Ciawi        West Java  ...     Enchanted Isle
# 2      Singapore     Central           Rochor  ...     Seacoast Hotel
# 3      Singapore       North           Yishun  ...  Night In Paradise
# 4       Cambodia  Phnom Trop           Pursat  ...    Tiny Digs Hotel
#
#   Hotel Rating  Payment Mode                   Bank Name  No. Of Days.1  \
# ...

# %%
# Number of rows and colunms

hotel.shape
# Out:
# (66535, 27)

# %%
# data description

hotel.describe()
# Out:
#                Year           Age  No. Of People   No. Of Days         Rooms  \
# count  66535.000000  66535.000000   66535.000000  66535.000000  66535.000000
# mean    2015.132396     38.436402       3.995852      3.233787      2.283400
# std        2.885649     11.556566       2.000116      3.377939      1.031154
# min     2010.000000     19.000000       1.000000      1.000000      1.000000
# 25%     2013.000000     28.000000       2.000000      1.000000      1.000000
# 50%     2015.000000     38.000000       4.000000      2.000000      2.000000
# 75%     2018.000000     48.000000       6.000000      4.000000      3.000000
# max     2019.000000     58.000000       7.000000     97.000000      4.000000
#
#        Hotel Rating  No. Of Days.1       Rooms.1  Booking Price[SGD]  \
# count  66535.000000   66535.000000  66535.000000        66535.000000
# mean       4.288508       3.233787      2.283400          214.054212
# ...

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66535 entries, 0 to 66534
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Booking ID           66535 non-null  object
#  1   Date of Booking      66535 non-null  datetime64[ns]
#  2   Year                 66535 non-null  int64
#  3   Time                 66535 non-null  object
#  4   Customer ID          66535 non-null  object
#  5   Gender               66535 non-null  object
#  6   Age                  66535 non-null  int64
#  7   Origin Country       66535 non-null  object
#  8   State                66535 non-null  object
#  9   Location             66535 non-null  object
#  10  Destination Country  66535 non-null  object
#  11  Destination City     66535 non-null  object
#  12  No. Of People        66535 non-null  int64
#  13  Check-in date        66535 non-null  datetime64[ns]
#  14  No. Of Days          66535 non-null  int64
# ...

# %%
#checking for missing values

hotel.isnull().sum()
# Out:
# Booking ID             0
# Date of Booking        0
# Year                   0
# Time                   0
# Customer ID            0
# Gender                 0
# Age                    0
# Origin Country         0
# State                  0
# Location               0
# Destination Country    0
# Destination City       0
# No. Of People          0
# Check-in date          0
# No. Of Days            0
# Check-Out Date         0
# Rooms                  0
# Hotel Name             0
# Hotel Rating           0
# Payment Mode           0
# Bank Name              0
# No. Of Days.1          0
# Rooms.1                0
# Booking Price[SGD]     0
# Discount               0
# GST                    0
# Profit Margin          0
# dtype: int64

# %%
hotel.shape
# Out:
# (66535, 27)

# %%
#removing of columns that won't be needed for the analysisa

hotel=hotel.drop(columns=['Booking ID','Time','State','Destination City','State','Check-in date','Check-Out Date','Rooms','Rooms.1','No. Of Days.1','Bank Name'])

# %%
hotel=hotel.drop(columns=['Customer ID',])

# %%
hotel['Date of Booking']=pd.to_datetime(hotel['Date of Booking'], format='%m/%d/%y')
hotel.head()
# Out:
#   Date of Booking  Month  Year  Gender  Age Origin Country         Location  \
# 0      2010-01-01      1  2010    Male   42       Malaysia  Iskandar Puteri
# 1      2010-01-01      1  2010  Female   44      Indonesia        West Java
# 2      2010-01-01      1  2010  Female   31      Singapore           Rochor
# 3      2010-01-01      1  2010    Male   28      Singapore           Yishun
# 4      2010-01-01      1  2010    Male   44       Cambodia           Pursat
#
#   Destination Country  No. Of People  No. Of Days         Hotel Name  \
# 0             Denmark              1            8       Hotel Triton
# 1            Colombia              3            1     Enchanted Isle
# 2             Germany              3            7     Seacoast Hotel
# 3              Canada              3            4  Night In Paradise
# 4               Kenya              5            3    Tiny Digs Hotel
#
#    Hotel Rating Payment Mode  Booking Price[SGD]  Discount   GST  \
# ...

# %%
hotel['Month']= hotel['Date of Booking'].dt.month

# %%
hotel.head()
# Out:
#   Date of Booking  Year  Gender  Age Origin Country         Location  \
# 0      2010-01-01  2010    Male   42       Malaysia  Iskandar Puteri
# 1      2010-01-01  2010  Female   44      Indonesia        West Java
# 2      2010-01-01  2010  Female   31      Singapore           Rochor
# 3      2010-01-01  2010    Male   28      Singapore           Yishun
# 4      2010-01-01  2010    Male   44       Cambodia           Pursat
#
#   Destination Country  No. Of People  No. Of Days         Hotel Name  \
# 0             Denmark              1            8       Hotel Triton
# 1            Colombia              3            1     Enchanted Isle
# 2             Germany              3            7     Seacoast Hotel
# 3              Canada              3            4  Night In Paradise
# 4               Kenya              5            3    Tiny Digs Hotel
#
#    Hotel Rating Payment Mode  Booking Price[SGD]  Discount   GST  \
# 0           4.3       Wallet                 243      0.01  0.07
# ...

# %%
last_col=hotel.pop('Month')
hotel1=hotel.insert(1,'Month', last_col)
print(hotel)
# Out:
#       Date of Booking  Month  Year  Gender  Age Origin Country  \
# 0          2010-01-01      1  2010    Male   42       Malaysia
# 1          2010-01-01      1  2010  Female   44      Indonesia
# 2          2010-01-01      1  2010  Female   31      Singapore
# 3          2010-01-01      1  2010    Male   28      Singapore
# 4          2010-01-01      1  2010    Male   44       Cambodia
# ...               ...    ...   ...     ...  ...            ...
# 66530      2019-12-31     12  2019  Female   42      Singapore
# 66531      2019-12-31     12  2019  Female   54      Singapore
# 66532      2019-12-31     12  2019  Female   57      Singapore
# 66533      2019-12-31     12  2019  Female   44       Thailand
# 66534      2019-12-31     12  2019  Female   52        Vietnam
#
#               Location Destination Country  No. Of People  No. Of Days  \
# 0      Iskandar Puteri             Denmark              1            8
# ...

# %% [markdown]
# ## DATA EXPLORATORY AND VISUALISATION

# %%
# New hotel booking dataset after the preparation
hotel.head()
# Out:
#   Date of Booking  Month  Year  Gender  Age Origin Country         Location  \
# 0      2010-01-01      1  2010    Male   42       Malaysia  Iskandar Puteri
# 1      2010-01-01      1  2010  Female   44      Indonesia        West Java
# 2      2010-01-01      1  2010  Female   31      Singapore           Rochor
# 3      2010-01-01      1  2010    Male   28      Singapore           Yishun
# 4      2010-01-01      1  2010    Male   44       Cambodia           Pursat
#
#   Destination Country  No. Of People  No. Of Days         Hotel Name  \
# 0             Denmark              1            8       Hotel Triton
# 1            Colombia              3            1     Enchanted Isle
# 2             Germany              3            7     Seacoast Hotel
# 3              Canada              3            4  Night In Paradise
# 4               Kenya              5            3    Tiny Digs Hotel
#
#    Hotel Rating Payment Mode  Booking Price[SGD]  Discount   GST  \
# ...

# %%
#Getting the preferred hotel based on the number of times it was booked
def count_rows(rows):
    return len(rows)
preferred_hotel = hotel.groupby(['Hotel Name']).apply(count_rows).reset_index(name='Count')
preferred_hotel_sorted= preferred_hotel.sort_values('Count', ascending=False)
print(preferred_hotel_sorted)
# Out:
#              Hotel Name  Count
# 157         Grand Hyatt    221
# 401       Secret Mirage    146
# 116      Enchanted Isle    146
# 8             Ace Hotel    146
# 241    Inn It To Win It    141
# ..                  ...    ...
# 466        The Corridor     82
# 227  Hotel Minute Masti     81
# 431  Star of Africa B&B     76
# 413  Simply Charmed B&B     75
# 467   The Cottage Motel     73
#
# [614 rows x 2 columns]

# %%
#peferred hotel based on hotel rating
preferred_hotel = hotel.groupby(['Hotel Name','Hotel Rating']).size().reset_index(name='Count')
preferred_hotel_sorted= preferred_hotel.sort_values('Count', ascending=False)
print(preferred_hotel_sorted)
# Out:
#                 Hotel Name  Hotel Rating  Count
# 3825   Reefs Resort & Club           4.5     36
# 4239         Secret Mirage           4.2     36
# 1675           Grand Hyatt           4.6     35
# 1671           Grand Hyatt           4.2     35
# 1238        Enchanted Isle           4.2     33
# ...                    ...           ...    ...
# 5969       The White sands           3.7      1
# 2234     Hotel De La Crème           3.3      1
# 4140  Scarlet Bliss Hotels           3.3      1
# 2213         Hotel Da Viva           3.3      1
# 2619         Island Resort           3.3      1
#
# [6476 rows x 3 columns]

# %%
#country most visited
def count_rows(rows):
    return len(rows)
most_visited_country = hotel.groupby(['Destination Country']).apply(count_rows).reset_index(name='Count')
most_visited_country_sorted= most_visited_country.sort_values('Count', ascending=False)
print(most_visited_country_sorted)

# %% [markdown]
# #### Most visted country based on the data is New Zealand

# %%
def count_rows(rows):
    return len(rows)
pm = hotel.groupby(['Payment Mode']).apply(count_rows).reset_index(name='Count')
pms= pm.sort_values('Count', ascending=False)
print(pms)
# Out:
#        Payment Mode  Count
# 3  Internet Banking  13445
# 2        Debit Card  13363
# 4            Wallet  13314
# 1       Credit Card  13265
# 0               COD  13148

# %%
#most popular payment method
plt.figure(figsize=(8,6))
plt.title('Most Popular Payment Method')
sns.countplot(hotel['Payment Mode'])
# Out:
# C:\Users\Daisy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Most Popular Payment Method'}, xlabel='Payment Mode', ylabel='count'>

# %%
plt.title('Relationship Between Gender and Booking Price')
sns.boxplot(x=hotel['Gender'], y=hotel['Booking Price[SGD]'])
# Out:
# <AxesSubplot:title={'center':'Relationship Between Gender and Booking Price'}, xlabel='Gender', ylabel='Booking Price[SGD]'>

# %%
plt.title('Most Booking by Gender')
sns.countplot(hotel['Gender'])
# Out:
# C:\Users\Daisy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Most Booking by Gender'}, xlabel='Gender', ylabel='count'>

# %%
xdata=[0,1,2,3,4,5]
plt.figure(figsize=(12,10))
sns.barplot(y=hotel['Destination Country'], x=hotel['Hotel Rating'])
plt.xticks(xdata)
# Out:
# ([<matplotlib.axis.XTick at 0x1fc37a88c10>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.lineplot(x='Month', y='Booking Price[SGD]', data=hotel).set_title('Booking Sales Per Month')
# Out:
# Text(0.5, 1.0, 'Booking Sales Per Month')

# %%
year=hotel.groupby(['Year']).size()
year
# Out:
# Year
# 2010    4797
# 2011    5309
# 2012    5607
# 2013    5525
# 2014    5905
# 2015    6292
# 2016    6212
# 2017    8571
# 2018    8816
# 2019    9501
# dtype: int64

# %%
sns.lineplot(x='Year', y='Booking Price[SGD]', data=hotel).set_title('Booking Sales Per Month')
# Out:
# Text(0.5, 1.0, 'Booking Sales Per Month')
